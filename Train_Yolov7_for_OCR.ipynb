# %%
# mount google drive to colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# define paths
PATH = '/content/gdrive/MyDrive/DPA/'
YOLO_PATH = PATH + 'yolov7'

# %%
# %cd {YOLO_PATH}
# Out:
# /content/gdrive/MyDrive/DPA/yolov7

# %%
# !pip install roboflow -q
from roboflow import Roboflow

rf = Roboflow(api_key="hdIkV92aiHa5J0X5brrf")
project = rf.workspace("sa-sa-d6awq").project("ocr-rzlyj")
dataset = project.version(8).download("yolov7")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to OCR-8 in yolov7pytorch:: 100%|██████████| 1137/1137 [00:06<00:00, 167.80it/s]

# %%
# !python {YOLO_PATH}/train.py \
--batch 16 \
--cfg {YOLO_PATH}/cfg/training/yolov7.yaml \
--epochs 100 \
--data {YOLO_PATH}/OCR-8/data.yaml \
--weights 'yolov7.pt' \
--device 0
# Out:
# YOLOR 🚀 v0.1-104-g941b94c torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='/content/gdrive/MyDrive/DPA/yolov7/cfg/training/yolov7.yaml', data='/content/gdrive/MyDrive/DPA/yolov7/OCR-8/data.yaml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp4', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python {YOLO_PATH}/detect.py \
--weights {YOLO_PATH}/runs/train/exp4/weights/best.pt \
--conf 0.3 \
--source "/content/gdrive/MyDrive/DPA/my_images/" \
--save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.3, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='/content/gdrive/MyDrive/DPA/my_images/', update=False, view_img=False, weights=['/content/gdrive/MyDrive/DPA/yolov7/runs/train/exp4/weights/best.pt'])
# YOLOR 🚀 v0.1-104-g941b94c torch 1.13.1+cu116 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36600440 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...
